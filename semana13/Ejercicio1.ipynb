# %%
#Se importan las librerias que voy a usar.
import matplotlib.pyplot as plt #graficas.
import numpy as np #gráfica para los arreglos.
# %matplotlib inline

# %%
texto= 'Ejercicio 1: Circulos con puntos, paso a paso.'

# %%
i=np.random.rand(10)
j=np.random.rand(10)
plt.scatter(i,j) 
z=np.array([i,j])
print (z)
print (len(z)) 
print (z[1,1])
# Out:
# [[0.88845614 0.17446148 0.19830155 0.90369214 0.38301482 0.19317884
#   0.50088238 0.02754157 0.4105831  0.11628389]
#  [0.9325884  0.8869673  0.75155968 0.80752082 0.86576147 0.59692009
#   0.069775   0.31451612 0.06793088 0.87400694]]
# 2
# 0.8869673026220445

# %%
for i in range(0,361,36):
    y=(0.1*np.sin(i))
    x=(0.1*np.cos(i))
    print(x)
    print(y)
    plt.scatter(x,y,color='green')
# Out:
# 0.1
# 0.0
# -0.012796368962740468
# -0.09917788534431159
# -0.09672505882738824
# 0.025382336276203628
# 0.037550959776701205
# 0.09268185054177851
# 0.08711474010323435
# -0.04910215938984694
# -0.059846006905785815
# -0.08011526357338306
# -0.07179850839697137
# 0.06960584883449115
# 0.07822121099422713
# 0.0623012211003653
# 0.051779558865081336
# -0.08555043707508209
# -0.09147301779353752
# -0.04040652194563607
# -0.028369109148652732
# 0.09589157234143066

# %%
for k in range (10): ##esto for se ejecuta 20 veces
    u=z[0,k]
    l=z[1,k]
    plt.scatter(u,l, color='red')##Se imprimen los centros de los circulos
    if k<5:
        for i in range(0,361,36): ##Establezco las condiciones.
            y=((0.1)*np.sin(i)) ## Continuo con el calculo.
            x=((0.1)*np.cos(i))
            plt.scatter(x+u,y+l, color='black')
